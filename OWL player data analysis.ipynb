# %% [markdown]
# # Overwatch League Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("phs_2019/phs_2019_playoffs.csv")
df.shape
# Out:
# (103232, 10)

# %%
df["map_type"].unique()
df["stat_name"].unique()
# Out:
# array(['All Damage Done', 'Assists', 'Average Time Alive',
#        'Barrier Damage Done', 'Damage - Quick Melee', 'Damage Blocked',
#        'Damage Done', 'Damage Taken', 'Deaths', 'Eliminations',
#        'Environmental Deaths', 'Final Blows', 'Healing Done',
#        'Hero Damage Done', 'Melee Final Blows',
#        'Melee Percentage of Final Blows', 'Multikills', 'Objective Kills',
#        'Objective Time', 'Shots Fired', 'Time Alive',
#        'Time Building Ultimate', 'Time Elapsed per Ultimate Earned',
#        'Time Holding Ultimate', 'Time Played',
#        'Ultimates Earned - Fractional', 'Ultimates Used',
#        'Weapon Accuracy', 'Critical Hit Accuracy', 'Critical Hit Kills',
#        'Critical Hits', 'Damage - Boosters', 'Damage - Micro Missiles',
#        'Damage - Pistol', 'Damage - Weapon', 'Eliminations per Life',
#        'Healing Received', 'Mech Deaths', 'Mechs Called',
#        'Quick Melee Accuracy', 'Quick Melee Hits', 'Quick Melee Ticks',
# ...

# %%
doomdf = df[df["hero"] == "Doomfist"]
doomdf.head()
# Out:
#          start_time  match_id                              stage map_type  \
# 125  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 126  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 127  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 128  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 129  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
#
#     map_name player             team            stat_name      hero  \
# 125    Ilios  JinMu  Chengdu Hunters  Ability Damage Done  Doomfist
# 126    Ilios  JinMu  Chengdu Hunters      All Damage Done  Doomfist
# 127    Ilios  JinMu  Chengdu Hunters              Assists  Doomfist
# 128    Ilios  JinMu  Chengdu Hunters   Average Time Alive  Doomfist
# 129    Ilios  JinMu  Chengdu Hunters  Barrier Damage Done  Doomfist
#
#      stat_amount
# 125   961.369717
# 126  2233.311597
# 127     2.000000
# 128    22.473001
# 129   539.508279

# %%
df[df["stat_name"] == ""]
